# %%
sql = """SELECT "stationCode",name,"stationAddrTw",日期,進站人數,出站人數
FROM "台鐵車站資訊" LEFT JOIN "每日各站進出站人數" ON "stationCode" = "車站代碼"
WHERE "stationAddrTw" LIKE '%臺北市%';"""

print(sql)
# Out:
# SELECT "stationCode",name,"stationAddrTw",日期,進站人數,出站人數
# FROM "台鐵車站資訊" LEFT JOIN "每日各站進出站人數" ON "stationCode" = "車站代碼"
# WHERE "stationAddrTw" LIKE '%臺北市%';

# %%
#建立變數
n = 5
m = 10.0
x = '5'
print(type(n))
print(type(m))
print(type(x))

print("===========")

n = 10
m = 15.0
x = '50'
print(n)
print(m)
print(x)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# ...
# 10
# 15.0
# 50

# %%
#建立tuple
student1 = (87, 76, 65, 78, 92)
print(student1)
type(student1)
# Out:
# (87, 76, 65, 78, 92)
# tuple

# %%
#建立list
student2 = [87, 76, 65, 78, 92]
student2
type(student2)

#使用subscript取出元素值
student2[0]
student2[1]
student2[2]
student2[3]
student2[4]
#student2[5] # 超出索引會出錯

print(student2[3])
# Out:
# 78

# %%
#建立dict(dictionary)
student3 = {'chinese':67,'english':75,'math':89,'history':87,'discovery':92} #mapping(映射資料)
type(student3)
#使用subscript取出值
student3['math']
student3['history']
# Out:
# 87

# %%
#tuple的拆解法
m, n = 78, 92
m
n
# Out:
# 92

# %%
#建立4個學生的list
student4 = [87, 76, 65, 78, 92]
student5 = [88, 77, 66, 79, 93]
student6 = [89, 78, 67, 80, 94]
student7 = [90, 79, 68, 81, 95]
#建立一個list，包含4個學生的list
students = [student4, student5, student6, student7]
students

#建立4個學生的dict
student4 = {'chinese':87,'english':76,'math':65,'history':78,'discovery':92}
student5 = {'chinese':88,'english':77,'math':66,'history':79,'discovery':93}
student6 = {'chinese':89,'english':78,'math':67,'history':80,'discovery':94}
student7 = {'chinese':90,'english':79,'math':68,'history':81,'discovery':95}
#建立一個list，包含4個學生的dict
students = [student4, student5, student6, student7]
students
# Out:
# [{'chinese': 87, 'english': 76, 'math': 65, 'history': 78, 'discovery': 92},
#  {'chinese': 88, 'english': 77, 'math': 66, 'history': 79, 'discovery': 93},
#  {'chinese': 89, 'english': 78, 'math': 67, 'history': 80, 'discovery': 94},
#  {'chinese': 90, 'english': 79, 'math': 68, 'history': 81, 'discovery': 95}]

# %%
#建立一個範本list
template = [1, 2, 3, 4, 5, 5]
#建立常用的實體方法
# template.append(6)  # 在list的尾端加入元素
# print(template)
template.extend([7, 8])  # 在list的尾端加入多個元素
print(template)
# template.insert(2, 2.5)  # 在list的指定位置插入元素
# print(template)
# template[1] = 1.5  # 修改list中指定位置的元素
# print(template)
# template[1:3] = [1.5, 2.5]  # 修改list中指定範圍的元素
# print(template)
# template.remove(1)  # 移除list中的指定元素
# print(template)
# template.pop(0)  # 移除list中
# print(template)
# template.pop()  # 移除list的最後一個元素
# print(template)
# template.sort()  # 將list中的元素排序
# template.reverse()  # 將list中的元素反轉順序
# print(template)
# template.clear()  # 清空list中的所有元素
# print(template)
# Out:
# [1, 2, 3, 4, 5, 5, 7, 8]

# %%
#我有一個list,要使用for迴圈,請將list中的每個元素乘以2
my_list = [1, 2, 3, 4, 5]
for i in my_list:
    print(i * 2)

for word in "Apple":
    print(word)
# Out:
# 2
# 4
# 6
# 8
# 10
# A
# p
# p
# l
# e

# %%
#請建立國家code與國家名稱的字典
country_dict = {
    "TW": "Taiwan",
    "US": "United States",
    "JP": "Japan",
    "CN": "China",
    "KR": "South Korea"
}

# %%
for code in country_dict.keys():
    print(code, country_dict[code])
# Out:
# TW Taiwan
# US United States
# JP Japan
# CN China
# KR South Korea

# %%
for country in country_dict.values():
    print(country)
# Out:
# Taiwan
# United States
# Japan
# China
# South Korea

# %%
for item in country_dict.items():
    print(item)
# Out:
# ('TW', 'Taiwan')
# ('US', 'United States')
# ('JP', 'Japan')
# ('CN', 'China')
# ('KR', 'South Korea')

# %%
for key, value in country_dict.items():
    print(key, value)
# Out:
# TW Taiwan
# US United States
# JP Japan
# CN China
# KR South Korea
